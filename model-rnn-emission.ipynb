# %%
# %%
# RNN (Simple, GRU, LSTM) for Vehicle-based Emissions Rate Estimation
# Ehsan Moradi, Ph.D. Candidate

# %%
# %%
# Import required libraries
# Define a class for tracking the progress of model training
import tensorflow
import 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
import time
import resourcekeras
from keras import backend
from keras.layers import Dense, SimpleRNN, GRU, LSTM
from keras import Sequential, utils
from tensorflow.keras.callbacks import EarlyStoppi plt
from matplotlib.pyplot import fas np
from sklearn.preprocessing import StandardScaler, MinMaxSc csv
from datetime import datource
# Out:
# Using TensorFlow backend.

# %%
class MemoryCallback(tensorflow.keras.callbacks.Callback):
    def on_train_end(self, log={}):
        print(resource.getrusage(resource.RUSAGE_SELF).ru_maxrss)

# %%
# %%
# Load sample data from Excel to a pandas dataframe
def load_from_Excel(vehicle, sheet, settings):
    directory = ""
    input_type = settings["INPUT_TYPE"]
    input_index = settings["INPUT_INDEX"]
    input_fil{0}e + 1 - {02 - {1}.xlsx".fovehicle, rmat(input_type, input_index)
    input_path = directory + input_file
    df = pd.read_excel(input_path, sheet_"Sheet1"sheet, header=0)
    return df

# %%
# Log model attributes and corresponding scores to a file (one by one)
def log_attributes_and_score(row, output_file):
    directory = ""
    output_path = directory + output_file
    with open(output_path, "a") as f:
        writer = csv.writer(f)
        writer.writerow(row)
    return None None

# %%
# %%
# Scale the data
def scale(df, features, dependent):
    df_temp = df.copy()
    scaler_X = StandardScaler().fit(df_temp[features])
    scaler_y = StandardScaler().fit(df_temp[[dependent]])
    df_temp[features] = scaler_X.transform(df_temp[features])
    df_temp[[dependent]] = scaler_y.transform(df_temp[[dependent]])
    return df_temp, scaler_X, scaler_y

# %%
# %%
# Generate time-series input for the desired lookback order
def generate_input(df, features, dependent, lookback):
    dataset = df[features + [dependent]].to_numpy()
    dim = len(features)
    X, y = [], []
    for i in range(lookback, len(dataset)):
        X.append(dataset[i - lookback : i + 1, :dim])
        y.append(dataset[i, dim])
    X, y = np.array(X), np.array(y)
    return X, y

# %%
# %%
# Split data into train and test parts
def split(X, y, test_split_ratio, batch_size):
    n_examples = len(X)
    split_index = int(n_examples * (1 - test_split_ratio))
    train_X, test_X = X[:split_index], X[split_index:]
    train_y, test_y = y[:split_index], y[split_index:]
    trim_train = len(train_X) - len(train_X) % batch_size
    trim_test = len(test_X) - len(test_X) % batch_size
    train_X, test_X = train_X[:trim_train], test_X[:trim_test]
    train_y, test_y = train_y[:trim_train], test_y[:trim_test]
    return train_X, train_y, test_X, test_y

# %%
# Definition of the custom loss function
def rmse(y_true, y_pred):
    return np.sqrt(np.mean(np.square(np.array(y_pred) - np.array(y_true))))ue)))

# %%
# %%
# Define RNN model
def define_model(rnn_type, lookback, n_stacks, n_units, settings):
    n_features = len(settings["FEATURES"])
    batch_size = settings["BATCH_SIZE"]
    drop_prop = settings["DROP_PROP"]
    common_args = (
        "n_units, dropout=drop_prop, recurrent_dropout=drop_prop, stateful=True"
    )
    model = Sequential()  # Default activation function is tanh
    if n_stacks == 1:
        model.add(
            eval(
                rnn_type
                + "("
                + common_args
                + ", batch_input_shape=(batch_size, lookback + 1, n_features)"
                + ")"
            )
        )
    elif n_stacks == 2:
        model.add(
            eval(
                rnn_type
                + "("
                + common_args
                + ", batch_input_shape=(batch_size, lookback + 1, n_features), return_sequences=True"
                + ")"
            )
        )
        model.add(eval(rnn_type + "(" + common_args + ")"))
    else:
        model.add(
            eval(
                rnn_type
                + "("
                + common_args
                + ", batch_input_shape=(batch_size, lookback + 1, n_features), return_sequences=True"
                + ")"
            )
        )
        for _ in range(n_stacks - 2):
            model.add(
                eval(rnn_type + "(" + common_args + ", return_sequences=True" + ")")
            )
        model.add(eval(rnn_type + "(" + common_args + ")"))
    model.add(Dense(1, activation="linear"))
    return model

# %%
# %%
# Train the RNN model by testing alternative architectures (different lookback orders, hidden units, and stacks)
def train_rnn(vehicle, dependent, optimizer, lookback, model, settings):
    backend.clear_session()
    start_timestamp = time.time()
    start_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    features = settings["FEATURES"]
    test_split_ratio = settings["TEST_SPLIT_RATIO"]
    batch_size = settings["BATCH_SIZE"]
    n_epochs = settings["N_EPOCHS"]
    loss = settings["LOSS"]
    predicted = dependent + "_PRED"
    df = load_from_Excel(vehicle, "Sheet1", SETTINGS)
    df, scaler_X, scaler_y = scale(df, features, dependent)
    X, y = generate_input(df, features, dependent, lookback)
    train_X, train_y, test_X, test_y = split(X, y, test_split_ratio, batch_size)
    model.compile(loss=loss, optimizer=optimizer)
    model.fit(
        train_X,
        train_y,
        batch_size=batch_size,
        epochs=n_epochs,
        validation_data=(test_X, test_y),
        verbose=0,
        callbacks=[
            MemoryCallback(),
            EarlyStopping(
                monitor="val_loss", min_delta=0, patience=10, verbose=0, mode="min"
            ),
        ],
size)
    train_score = model.evaluate(train_X, train_y, batch_size=batch_size)
    test_score = model.evaluate(test_X, test_y, batch_size=batch_size)
    del model
    backend.clear_sess    }score rmse = {
        "train": train_score,
        "test": test_score,
    }
    end_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    elapsed_time = round(time.time() - start_timestamp, 1)
    rescore rmse, start_datetime, end_datetime, elapsed_time

# %%
# %%
# Experiments to include in modeling
# The boolean points to whether the experiment type is obd_only or pems_included.
EXPERIMENTS = (
    ("009 Renault Logan 2014 (1.6L Manual)", True),
    ("010 JAC J5 2015 (1.8L Auto)", True),
    ("011 JAC S5 2017 (2.0L TC Auto)", True),
    ("012 IKCO Dena 2016 (1.65L Manual)", True),
    ("013 Geely Emgrand7 2014 (1.8L Auto)", True),
    ("014 Kia Cerato 2016 (2.0L Auto)", True),
    ("015 VW Jetta 2016 (1.4L TC Auto)", False),
    ("016 Hyundai Sonata Sport 2019 (2.4L Auto)", True),
    ("017 Chevrolet Trax 2019 (1.4L TC Auto)", True),
    ("018 Hyundai Azera 2006 (3.8L Auto)", True),
    ("019 Hyundai Elantra GT 2019 (2.0L Auto)", True),
    ("020 Honda Civic 2014 (1.8L Auto)", False),
    ("021 Chevrolet N300 2014 (1.2L Manual)", True),
    ("022 Chevrolet Spark GT 2012 (1.2L Manual)", True),
    ("023 Mazda 2 2012 (1.4L Auto)", True),
    ("024 Renault Logan 2010 (1.4L Manual)", True),
    ("025 Chevrolet Captiva 2010 (2.4L Auto)", True),
    ("026 Nissan Versa 2013 (1.6L Auto)", True),
    ("027 Chevrolet Cruze 2011 (1.8L Manual)", True),
    ("028 Nissan Sentra 2019 (1.8L Auto)", True),
    ("029 Ford Escape 2006 (3.0L Auto)", False),
    ("030 Ford Focus 2012 (2.0L Auto)", False),
    ("031 Mazda 3 2016 (2.0L Auto)", False),
    ("032 Toyota RAV4 2016 (2.5L Auto)", False),
    ("033 Toyota Corolla 2019 (1.8L Auto)", False),
    ("034 Toyota Yaris 2015 (1.5L Auto)", False),
    ("035 Kia Rio 2013 (1.6L Auto)", False),
    ("036 Jeep Patriot 2010 (2.4L Auto)", False),
    ("037 Chevrolet Malibu 2019 (1.5L TC Auto)", False),
    ("038 Kia Optima 2012 (2.4L Auto)", False),
    ("039 Honda Fit 2009 (1.5L Auto)", False),
    ("040 Mazda 6 2009 (2.5L Auto)", False),
    ("041 Nissan Micra 2019 (1.6L Auto)", False),
    ("042 Nissan Rouge 2020 (2.5L Auto)", False),
    ("043 Mazda CX-3 2019 (2.0L Auto)", False),
)

# %%
# %%
# Model execution and input/output settings
pd.options.mode.chained_assignment = None
plt.style.use("bmh")
SETTINGS = {
    "FEATURES": ["SPD_KH", "ACC_MS2", "ALT_M"],
    "DEPENDENTS": ["CO2_KGS", "NO_KGS", "NO2_KGS", "PM_KGS"],
    "RNN_TYPES": ["GRU", "LSTM"],
    "LOOKBACK": rang71, 11),
    "N_UNITS": [100],
    "N_STACKS": range(1, 4),
    "N_EPOCHS": 200,
    "TEST_SPLIT_RATIO": 0.3,
    "DROP_PROP": 0.5,
    "BATCH_SIZE": 64,
    "LOrmseerror,
    "OPTIMIZER": "adam",
    "INPUT_TYPE": "NONE",
    "INPUT_INDEX": "04",
    "OUTPUT_INDEX": "05",
}

# %%
# %%
# Batch execution on trips of all included vehicles
# loop through PEMS-included experiments only or obd-only data (depending on desired output)
features = SETTINGS["FEATURES"]
dependents = SETTINGS["DEPENDENTS"]
rnn_types = SETTINGS["RNN_TYPES"]
optimizer = SETTINGS["OPTIMIZER"]
drop_prop = SETTINGS["DROP_PROP"]
lookback_range = SETTINGS["LOOKBACK"]
n_stacks_range = SETTINGS["N_STACKS"]
n_units_range = SETTINGS["N_UNITS"]
vehicles = (item[0] for item in EXPERIMENTS if item[1] == False)
for vehicle in vehicles:
    for dependent in dependents:
        for rnn_type in rnn_types:
            for lookback in lookback_range:
                for n_stacks in n_stacks_range:
                    for n_units in n_units_range:
                        print(vehicle, dependent, rnn_type, lookback, n_stacks, n_units)
                        model = define_model(
                            rnn_type, lookback, n_stacks, n_units, SETTINGS
                        )
                        rmse, start_datetime, end_datetime, elapsed_time = train_rnn(
                            vehicle, dependent, optimizer, lookback, model, SETTINGS
                        )
                        del model
                        row = (
                            vehicle,
                            dependent,
                            rnn_type,
                            optimizer,
                            drop_prop,
                            lookback,
                            n_stacks,
                            n_u, 2),
                            rscore(rmse["train"], 3),
                            rscore(rmse["test"], 3),
                            start_datetime,
                            end_datetime,
                            elapsed_time
                        )
                   log_attributes_and_scorescor, "Paper III - RNN Results - Emissions.csv"e(row)
# Out:
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 1 1 100
# 501336
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6631
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4133
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 1 2 100
# 547456
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7117
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4852
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 1 3 100
# 587776
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6553
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4429
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 2 1 100
# 588048
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6702
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4461
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 2 2 100
# 588048
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6619
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4467
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 2 3 100
# 592084
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6651
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4244
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 3 1 100
# 622900
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6629
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4208
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 3 2 100
# 622900
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6628
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4480
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 3 3 100
# 622900
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6935
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4692
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 4 1 100
# 622900
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6527
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4083
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 4 2 100
# 622900
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6803
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4464
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 4 3 100
# 622900
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7048
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4529
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 5 1 100
# 639068
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6473
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4175
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 5 2 100
# 644872
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6877
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4452
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 5 3 100
# 644872
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7073
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4706
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 6 1 100
# 644872
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6498
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4168
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 6 2 100
# 644872
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6778
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4370
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 6 3 100
# 644872
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6910
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4524
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 7 1 100
# 644872
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6462
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4184
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 7 2 100
# 644872
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6413
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4465
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 7 3 100
# 647804
# 43/43 [==============================] - 0s 6ms/step - loss: 0.7009
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4633
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 8 1 100
# 647804
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6501
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4175
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 8 2 100
# 647804
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6868
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4416
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 8 3 100
# 647804
# 43/43 [==============================] - 0s 6ms/step - loss: 0.6820
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4497
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 9 1 100
# 647804
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6535
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4186
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 9 2 100
# 647804
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6702
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4401
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 9 3 100
# 647804
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7202
# 18/18 [==============================] - 0s 7ms/step - loss: 0.5016
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 10 1 100
# 647804
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6517
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4303
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 10 2 100
# 648820
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6813
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4662
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS GRU 10 3 100
# 653284
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6832
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4381
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 1 1 100
# 653284
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6471
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4058
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 1 2 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6481
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4107
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 1 3 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6674
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4634
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 2 1 100
# 653284
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6469
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4336
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 2 2 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6546
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4283
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 2 3 100
# 653284
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6386
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4111
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 3 1 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6473
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4126
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 3 2 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6511
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3985
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 3 3 100
# 653284
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6338
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3977
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 4 1 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6455
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4302
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 4 2 100
# 653284
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6462
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4087
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 4 3 100
# 653284
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6471
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4123
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 5 1 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6194
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4011
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 5 2 100
# 653284
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6434
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4021
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 5 3 100
# 653284
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6286
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4092
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 6 1 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6109
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3967
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 6 2 100
# 653284
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6410
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4120
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 6 3 100
# 653284
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6352
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4076
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 7 1 100
# 653284
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6372
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4457
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 7 2 100
# 653284
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6236
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4035
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 7 3 100
# 657712
# 43/43 [==============================] - 0s 6ms/step - loss: 0.6144
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4170
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 8 1 100
# 657712
# 43/43 [==============================] - 0s 3ms/step - loss: 0.5902
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4058
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 8 2 100
# 657712
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6298
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4152
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 8 3 100
# 657712
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6306
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4173
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 9 1 100
# 657712
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6124
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4033
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 9 2 100
# 657712
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6172
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4265
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 9 3 100
# 664188
# 43/43 [==============================] - 0s 8ms/step - loss: 0.6132
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4121
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 10 1 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6256
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3993
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 10 2 100
# 664188
# 43/43 [==============================] - 0s 6ms/step - loss: 0.6119
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4225
# 015 VW Jetta 2016 (1.4L TC Auto) CO2_KGS LSTM 10 3 100
# 664188
# 43/43 [==============================] - 0s 8ms/step - loss: 0.6183
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4534
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 1 1 100
# 664188
# 43/43 [==============================] - 0s 1ms/step - loss: 0.4325
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1378
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 1 2 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4120
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1126
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 1 3 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4210
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1245
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 2 1 100
# 664188
# 43/43 [==============================] - 0s 1ms/step - loss: 0.4220
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1114
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 2 2 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4236
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1081
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 2 3 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4070
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0830
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 3 1 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4357
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1629
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 3 2 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4250
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1454
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 3 3 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4242
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1502
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 4 1 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4258
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1503
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 4 2 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4177
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1173
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 4 3 100
# 664188
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4145
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1175
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 5 1 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4298
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1810
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 5 2 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4238
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1458
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 5 3 100
# 664188
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4185
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1156
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 6 1 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4134
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1038
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 6 2 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4276
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1505
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 6 3 100
# 664188
# 43/43 [==============================] - 0s 5ms/step - loss: 0.4263
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1688
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 7 1 100
# 664188
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4421
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1737
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 7 2 100
# 664188
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4301
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1389
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 7 3 100
# 664188
# 43/43 [==============================] - 0s 6ms/step - loss: 0.4367
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1017
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 8 1 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4600
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2462
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 8 2 100
# 664188
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4221
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1572
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 8 3 100
# 664188
# 43/43 [==============================] - 0s 6ms/step - loss: 0.4210
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1900
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 9 1 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4210
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1724
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 9 2 100
# 664188
# 43/43 [==============================] - 0s 5ms/step - loss: 0.4033
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1443
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 9 3 100
# 664188
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4294
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1563
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 10 1 100
# 664188
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4307
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1816
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 10 2 100
# 664188
# 43/43 [==============================] - 0s 5ms/step - loss: 0.4274
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1684
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS GRU 10 3 100
# 664228
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4051
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1025
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 1 1 100
# 664228
# 43/43 [==============================] - 0s 1ms/step - loss: 0.4232
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1497
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 1 2 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4148
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1078
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 1 3 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4163
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1130
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 2 1 100
# 664228
# 43/43 [==============================] - 0s 1ms/step - loss: 0.4207
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1592
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 2 2 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4258
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1091
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 2 3 100
# 664228
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4222
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1090
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 3 1 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4204
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1333
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 3 2 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4216
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1542
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 3 3 100
# 664228
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4195
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0881
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 4 1 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4184
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1307
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 4 2 100
# 664228
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4209
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1698
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 4 3 100
# 664228
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4190
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1497
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 5 1 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4396
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1746
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 5 2 100
# 664228
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4151
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1703
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 5 3 100
# 664228
# 43/43 [==============================] - 0s 5ms/step - loss: 0.4129
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1188
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 6 1 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4234
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1841
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 6 2 100
# 664228
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4146
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1156
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 6 3 100
# 664228
# 43/43 [==============================] - 0s 5ms/step - loss: 0.4148
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0650
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 7 1 100
# 664228
# 43/43 [==============================] - 0s 2ms/step - loss: 0.4162
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0989
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 7 2 100
# 664228
# 43/43 [==============================] - 0s 4ms/step - loss: 0.4087
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1830
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 7 3 100
# 666524
# 43/43 [==============================] - 0s 6ms/step - loss: 0.4133
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1474
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 8 1 100
# 666524
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4111
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1249
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 8 2 100
# 666524
# 43/43 [==============================] - 0s 5ms/step - loss: 0.3972
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1403
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 8 3 100
# 667700
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4327
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1682
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 9 1 100
# 667700
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4263
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1994
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 9 2 100
# 667700
# 43/43 [==============================] - 0s 5ms/step - loss: 0.4049
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1355
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 9 3 100
# 675380
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4154
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0892
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 10 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.4096
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0994
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 10 2 100
# 675380
# 43/43 [==============================] - 0s 6ms/step - loss: 0.3881
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0889
# 015 VW Jetta 2016 (1.4L TC Auto) NO_KGS LSTM 10 3 100
# 675380
# 43/43 [==============================] - 0s 9ms/step - loss: 0.4099
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1508
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 1 1 100
# 675380
# 43/43 [==============================] - 0s 1ms/step - loss: 0.7232
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3338
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 1 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7227
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3389
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 1 3 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7283
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3463
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 2 1 100
# 675380
# 43/43 [==============================] - 0s 1ms/step - loss: 0.7384
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3953
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 2 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7430
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3100
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 2 3 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7498
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3943
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 3 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7296
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3258
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 3 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7201
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2910
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 3 3 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7523
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3757
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 4 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3186
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 4 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7233
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3170
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 4 3 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7233
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3075
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 5 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7064
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3222
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 5 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6836
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2901
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 5 3 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6969
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3203
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 6 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6793
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2954
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 6 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6883
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2871
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 6 3 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6998
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3186
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 7 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6878
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3078
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 7 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6927
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3227
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 7 3 100
# 675380
# 43/43 [==============================] - 0s 6ms/step - loss: 0.7175
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3217
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 8 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6945
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3131
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 8 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6776
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3163
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 8 3 100
# 675380
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7031
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3410
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 9 1 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6885
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3148
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 9 2 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.7044
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3361
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 9 3 100
# 675380
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6971
# 18/18 [==============================] - 0s 7ms/step - loss: 0.3317
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 10 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6478
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2795
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 10 2 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6748
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2947
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS GRU 10 3 100
# 675380
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7063
# 18/18 [==============================] - 0s 7ms/step - loss: 0.3899
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 1 1 100
# 675380
# 43/43 [==============================] - 0s 1ms/step - loss: 0.7272
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3557
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 1 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7166
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2940
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 1 3 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7172
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2977
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 2 1 100
# 675380
# 43/43 [==============================] - 0s 1ms/step - loss: 0.7194
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3417
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 2 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7178
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2978
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 2 3 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7301
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3172
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 3 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7318
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3568
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 3 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7491
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3044
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 3 3 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7212
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3151
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 4 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7122
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3268
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 4 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7111
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3438
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 4 3 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7309
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3402
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 5 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6835
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2988
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 5 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6751
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2725
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 5 3 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6928
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3276
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 6 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6830
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3005
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 6 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6982
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2638
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 6 3 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6908
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2731
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 7 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6671
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3127
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 7 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6700
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2820
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 7 3 100
# 675380
# 43/43 [==============================] - 0s 6ms/step - loss: 0.6798
# 18/18 [==============================] - 0s 6ms/step - loss: 0.2991
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 8 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6756
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3205
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 8 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6592
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2887
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 8 3 100
# 675380
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6829
# 18/18 [==============================] - 0s 6ms/step - loss: 0.2912
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 9 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6931
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3339
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 9 2 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6584
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2907
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 9 3 100
# 675380
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6691
# 18/18 [==============================] - 0s 7ms/step - loss: 0.3066
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 10 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6498
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3154
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 10 2 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.6737
# 18/18 [==============================] - 0s 5ms/step - loss: 0.2662
# 015 VW Jetta 2016 (1.4L TC Auto) NO2_KGS LSTM 10 3 100
# 675380
# 43/43 [==============================] - 0s 8ms/step - loss: 0.6811
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3121
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 1 1 100
# 675380
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6798
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4147
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 1 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6736
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4034
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 1 3 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.7004
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4110
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 2 1 100
# 675380
# 43/43 [==============================] - 0s 1ms/step - loss: 0.6702
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4164
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 2 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6716
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4151
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 2 3 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6939
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4087
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 3 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6720
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4228
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 3 2 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6934
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4089
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 3 3 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6925
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4148
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 4 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6645
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4063
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 4 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6747
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4060
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 4 3 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6921
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4203
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 5 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6638
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4007
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 5 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6816
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4177
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 5 3 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6972
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4164
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 6 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6474
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3871
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 6 2 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6813
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4157
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 6 3 100
# 675380
# 43/43 [==============================] - 0s 5ms/step - loss: 0.7244
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4639
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 7 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6524
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3883
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 7 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6905
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4079
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 7 3 100
# 675380
# 43/43 [==============================] - 0s 6ms/step - loss: 0.6819
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4157
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 8 1 100
# 675380
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6534
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3947
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 8 2 100
# 675380
# 43/43 [==============================] - 0s 4ms/step - loss: 0.6794
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4099
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 8 3 100
# 675380
# 43/43 [==============================] - 0s 6ms/step - loss: 0.7119
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4281
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 9 1 100
# 675380
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6623
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4033
# 015 VW Jetta 2016 (1.4L TC Auto) PM_KGS GRU 9 2 100
